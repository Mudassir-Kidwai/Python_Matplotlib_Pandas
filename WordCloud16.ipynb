# %%
# Simple WordCloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 

#text = 'all your base are belong to us all all all all all all all of your base base base'

text = 'Twitter, Pattern matching, Tagging, Suspension, Feature extraction, Social network services, Time frequency analysis, Real time systems, Media, Facebook, Internet, Browsers, Web pages, Mathematical Model, Electronic mail, MySpace, Asia, Technological Innovation, Sociology, Twitter, Reliability, Statistics, Market research, Social network analysis, Montoring, Delays, IC Modeling, Image edge detection, Stochastic process, Probabilistic logic, Social network services, Prediction algorithms, Games, IC Modeling, Monitoring, Twitter, Tagging, Data Mining, CS, NLP, Data Analysis, Data Mining, Laplace equations, Partitioning algorithms, Approximation algorithms, Data Models, Computational modeling, Iron, Monte Carlo Methods, Biological system modeling, Social network services, Mathematical models, Companies, Internet, Knowledge Engineering, Time measurement, Stability analysis, Social network services, Mathematical programming, Linear programming, Electronic mail, Bio Informatics, Quadratic Programming, Social network services, CS, Density measurement, Algorithms, Tv, Event detection, Social network services, Navigation, Resource management, Bicycle, Automobiles, Access control, Detection algorithm, Facebook, Clustering Algorithm, Privacy, Optimization, Consumption behaviour, Socioeconomic status, Communication network, purchase correlations, Social network services, Rats, Airports, Data Mining, Fires, Games, System Analysis and design, Predictive models, correlations, Facebook, CS, Algorithm Analysis, Facebook, Twitter, Sampling methods, Partitioning algorithms, Approximation algorithms, Electronic mail, Silicon, Heuristic Algorithm, Detection Algorithms, Partitioning Algorithms, Algorithms design and analysis, Image edge detection, Social Network Services, ML Algorithms, Data Mining, Computational modeling, Support vector machines, Social Network Services, Heuristic algorithm, Algorithm design and analysis, Data Structures, Indexes, Clustering Algorithm, Partitioning algorithm, Algorithms design and analysis, Approximation algorithm, CS, Electronic mail, Social Network services, Algorithm design and analysis, heuristic algorithm, Complex networks, adaptation models, Twitter, Geospatial analysis, Tagging, Estimation, Time measurement, Smoothing methods, Histograms, Social Network services, Detection algorithms, Context, Electronic mail, Organizations,Social network services, Electronic mail, Internet, Education, Splicing, Information management, Twitter, Predictive models, Eletronic mail, Mathematical models, Social Network Services, Training data, Estimation, Training, Urban Areas, Noise measurement, LinkedIn, Facebook, Approximation Algorithm, Greedy Algorithm, Advertising, Social network services, Classification algorithms, Negative feedback, Analytical models, Software, Optimization, Social Network Services, CS, Databases, Sentiment analysis, Message systems, Blogs, Sensitivity, Social Network Services, CS, ML, Aggregates, Standards, Electronic Mail, Companis, Games, Indexes, Social Network Services, Data mining, Printers, Data Mining, Data Models, Social Network services, CS, Predictive models, Prediction Algorithm, Feature extraction, IC Modeling, Social Network Services, Computational Modeling, Minimization, Media, Labeling, Twitter, Feature Extraction, Servers, Training, Electronic mail, Data mining, Web pages, Google, big data, Feature Redundancy, Predictive models, Social network services, Entropy, Semantics, Measurement, Urban Areas, Social Network Services, Context, Organizations, Algorithm design and analysis, Particle measurements, Atmospheric Measurement'

def generate_wordcloud(text): # optionally add: stopwords=STOPWORDS and change the arg below
    wordcloud = WordCloud(relative_scaling = 0.5,
                          stopwords = {','} # set or space-separated string
                          ).generate(text)
    #plt.figure( figsize=(20,10), facecolor='k' )
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

generate_wordcloud(text)
